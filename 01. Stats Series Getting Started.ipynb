# %%
import csv
print("I worked!")


i = 0
with open('data/usa.csv', newline='') as myFile:
    data = csv.reader(myFile)
    for row in data:
        print(i, row)
        i += 1
        if i > 100:
            break
# Out:
# I worked!
# 0 ['SEX', 'AGE', 'RACE', 'RACED', 'EDUC', 'EDUCD', 'INCTOT']
# 1 ['1', '73', '2', '200', '2', '25', '10000']
# 2 ['2', '31', '1', '100', '10', '101', '38500']
# 3 ['1', '41', '1', '100', '6', '64', '82000']
# 4 ['2', '48', '1', '100', '6', '63', '8700']
# 5 ['1', '16', '1', '100', '4', '40', '0']
# 6 ['2', '37', '2', '200', '6', '63', '18300']
# 7 ['2', '18', '2', '200', '5', '50', '0']
# 8 ['1', '17', '2', '200', '4', '40', '8800']
# 9 ['2', '7', '2', '200', '1', '14', '9999999']
# 10 ['2', '3', '2', '200', '0', '2', '9999999']
# 11 ['1', '32', '1', '100', '6', '63', '65000']
# 12 ['2', '54', '2', '200', '8', '81', '57000']
# 13 ['2', '1', '8', '801', '0', '1', '9999999']
# 14 ['1', '21', '2', '200', '7', '71', '18000']
# 15 ['1', '21', '5', '500', '7', '71', '0']
# 16 ['1', '20', '2', '200', '7', '71', '1200']
# 17 ['1', '67', '2', '200', '10', '101', '42500']
# 18 ['2', '72', '1', '100', '10', '101', '132040']
# 19 ['1', '80', '1', '100', '6', '63', '49100']
# ...
